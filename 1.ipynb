# %%
print("I found your existing policy with the following details:\n\n- **Policy Number:** PTXH0000016801\n- **Effective Date:** June 26, 2024\n- **Expiration Date:** June 26, 2025\n- **Policy Type:** Homeowners\n- **Full Term Premium:** $3,838.00\n- **Bill Method:** P (Payment)\n\n### Latest Transaction:\n- **Type:** PCH (Payment)\n- **Date:** June 26, 2024\n- **Premium:** $863.00\n\nIt seems there's no name associated with this policy. If you need assistance with anything specific regarding this policy or if you’d like to update your information, feel free to let me know! 😊")
# Out:
# I found your existing policy with the following details:
#
# - **Policy Number:** PTXH0000016801
# - **Effective Date:** June 26, 2024
# - **Expiration Date:** June 26, 2025
# - **Policy Type:** Homeowners
# - **Full Term Premium:** $3,838.00
# - **Bill Method:** P (Payment)
#
# ### Latest Transaction:
# - **Type:** PCH (Payment)
# - **Date:** June 26, 2024
# - **Premium:** $863.00
#
# It seems there's no name associated with this policy. If you need assistance with anything specific regarding this policy or if you’d like to update your information, feel free to let me know! 😊

# %%
print(""""{\n  \"projections\": [\n    {\n      \"month\": 1,\n      \"revenue\": 0.0,\n      \"expenses\": 8500000.0,\n      \"profit\": -8500000.0,\n      \"cumulative_profit\": -8500000.0,\n      \"customers\": 0,\n      \"growth_rate\": 0.0\n    },\n    {\n      \"month\": 2,\n      \"revenue\": 400000.0,\n      \"expenses\": 8300000.0,\n      \"profit\": -7900000.0,\n      \"cumulative_profit\": -16400000.0,\n      \"customers\": 8,\n      \"growth_rate\": 0.04\n    },\n    {\n      \"month\": 3,\n      \"revenue\": 840000.0,\n      \"expenses\": 8200000.0,\n      \"profit\": -7360000.0,\n      \"cumulative_profit\": -23760000.0,\n      \"customers\": 18,\n      \"growth_rate\": 0.05\n    },\n    {\n      \"month\": 4,\n      \"revenue\": 1386000.0,\n      \"expenses\": 8100000.0,\n      \"profit\": -6714000.0,\n      \"cumulative_profit\": -30474000.0,\n      \"customers\": 32,\n      \"growth_rate\": 0.05\n    },\n    {\n      \"month\": 5,\n      \"revenue\": 1975000.0,\n      \"expenses\": 8050000.0,\n      \"profit\": -6075000.0,\n      \"cumulative_profit\": -36549000.0,\n      \"customers\": 48,\n      \"growth_rate\": 0.05\n    },\n    {\n      \"month\": 6,\n      \"revenue\": 2664000.0,\n      \"expenses\": 8000000.0,\n      \"profit\": -5336000.0,\n      \"cumulative_profit\": -41885000.0,\n      \"customers\": 68,\n      \"growth_rate\": 0.05\n    },\n    {\n      \"month\": 7,\n      \"revenue\": 3420000.0,\n      \"expenses\": 8100000.0,\n      \"profit\": -4680000.0,\n      \"cumulative_profit\": -46565000.0,\n      \"customers\": 90,\n      \"growth_rate\": 0.04\n    },\n    {\n      \"month\": 8,\n      \"revenue\": 4210000.0,\n      \"expenses\": 8200000.0,\n      \"profit\": -3990000.0,\n      \"cumulative_profit\": -50555000.0,\n      \"customers\": 113,\n      \"growth_rate\": 0.04\n    },\n    {\n      \"month\": 9,\n      \"revenue\": 5040000.0,\n      \"expenses\": 8300000.0,\n      \"profit\": -3260000.0,\n      \"cumulative_profit\": -53815000.0,\n      \"customers\": 138,\n      \"growth_rate\": 0.04\n    },\n    {\n      \"month\": 10,\n      \"revenue\": 5905000.0,\n      \"expenses\": 8400000.0,\n      \"profit\": -2495000.0,\n      \"cumulative_profit\": -56310000.0,\n      \"customers\": 166,\n      \"growth_rate\": 0.04\n    },\n    {\n      \"month\": 11,\n      \"revenue\": 6790000.0,\n      \"expenses\": 8500000.0,\n      \"profit\": -1710000.0,\n      \"cumulative_profit\": -58020000.0,\n      \"customers\": 196,\n      \"growth_rate\": 0.04\n    },\n    {\n      \"month\": 12,\n      \"revenue\": 7690000.0,\n      \"expenses\": 8600000.0,\n      \"profit\": -910000.0,\n      \"cumulative_profit\": -58930000.0,\n      \"customers\": 227,\n      \"growth_rate\": 0.04\n    }\n  ],\n  \"assumptions\": {\n    \"initial_investment\": 100000000.0,\n    \"monthly_burn_rate\": 8000000.0,\n    \"customer_acquisition_cost\": 150000.0,\n    \"average_revenue_per_customer\": 34000.0,\n    \"churn_rate\": 0.15,\n    \"growth_rate_monthly\": 0.04\n  },\n  \"key_metrics\": {\n    \"break_even_month\": 15,\n    \"total_revenue_year1\": 36630000.0,\n    \"total_expenses_year1\": 98930000.0,\n    \"net_profit_year1\": -62300000.0,\n    \"customers_end_year1\": 227\n  }\n}""")
# Out:
# "{
#   "projections": [
#     {
#       "month": 1,
#       "revenue": 0.0,
#       "expenses": 8500000.0,
#       "profit": -8500000.0,
#       "cumulative_profit": -8500000.0,
#       "customers": 0,
#       "growth_rate": 0.0
#     },
#     {
#       "month": 2,
#       "revenue": 400000.0,
#       "expenses": 8300000.0,
#       "profit": -7900000.0,
#       "cumulative_profit": -16400000.0,
#       "customers": 8,
#       "growth_rate": 0.04
#     },
#     {
#       "month": 3,
#       "revenue": 840000.0,
#       "expenses": 8200000.0,
#       "profit": -7360000.0,
#       "cumulative_profit": -23760000.0,
#       "customers": 18,
#       "growth_rate": 0.05
#     },
#     {
#       "month": 4,
#       "revenue": 1386000.0,
#       "expenses": 8100000.0,
#       "profit": -6714000.0,
#       "cumulative_profit": -30474000.0,
#       "customers": 32,
#       "growth_rate": 0.05
#     },
#     {
#       "month": 5,
#       "revenue": 1975000.0,
#       "expenses": 8050000.0,
# ...
